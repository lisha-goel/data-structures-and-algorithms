# %% [markdown]
# <a href="https://colab.research.google.com/github/lisha-goel/data-structures-and-algorithms/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # this is title
# my data set

# %%
print("hello world")
# Out:
# hello world

# %%
3+5
# Out:
# 8

# %%
# !ls
# Out:
# sample_data

# %%
# !wget https://github.com/lisha-goel/data-structures-and-algorithms/blob/main/generated_data.csv
# Out:
# --2024-01-27 13:11:28--  https://github.com/lisha-goel/data-structures-and-algorithms/blob/main/generated_data.csv
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 189589 (185K) [text/plain]
# Saving to: ‘generated_data.csv’
#
# generated_data.csv  100%[===================>] 185.15K  --.-KB/s    in 0.05s
#
# 2024-01-27 13:11:29 (3.47 MB/s) - ‘generated_data.csv’ saved [189589/189589]

# %%
# !ls
# Out:
# generated_data.csv  sample_data

# %%
# !ls
# Out:
# generated_data.csv  sample_data

# %%
import pandas as pd

# %%
pd.read_csv("generated_data.csv", header=None).head()
# Out:
#                                      0      \
# 0  {"payload":{"allShortcutsEnabled":false
#
#                                       1               2      \
# 0  fileTree:{"":{"items":[{"name":"LICENSE"  path:"LICENSE"
#
#                  3                    4                 5      \
# 0  contentType:"file"}  {"name":"README.md"  path:"README.md"
#
#                  6                           7                        8      \
# 0  contentType:"file"}  {"name":"generate_data.py"  path:"generate_data.py"
#
#                  9      ...          12110                     12111  \
# 0  contentType:"file"}  ...  viewable:true  workflowRedirectUrl:null
#
#                         12112              12113         12114  \
# 0  symbols:{"timed_out":false  not_analyzed:true  symbols:[]}}
#
#               12115                       12116  \
# 0  copilotInfo:null  copilotAccessAllowed:false
#
#                                                12117  \
# ...

# %%
# !wget https://github.com/lisha-goel/data-structures-and-algorithms/raw/5291abe1f7544017b5f4dbf32a3a9fc773b5429d/generated_data.csv
# Out:
# --2024-01-27 13:25:16--  https://github.com/lisha-goel/data-structures-and-algorithms/raw/5291abe1f7544017b5f4dbf32a3a9fc773b5429d/generated_data.csv
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/lisha-goel/data-structures-and-algorithms/5291abe1f7544017b5f4dbf32a3a9fc773b5429d/generated_data.csv [following]
# --2024-01-27 13:25:16--  https://raw.githubusercontent.com/lisha-goel/data-structures-and-algorithms/5291abe1f7544017b5f4dbf32a3a9fc773b5429d/generated_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 159944 (156K) [text/plain]
# ...

# %%
# !ls
# Out:
# generated_data.csv  generated_data.csv.1  sample_data

# %%
df=pd.read_csv("generated_data.csv.2")

# %%
from google.colab import drive

# %%
len(df)
# Out:
# 3000

# %%
df.head()
# Out:
#                Name          Mobile Number  Age                   Company
# 0      Norma Fisher       487-364-7593x824   57              Archer-Patel
# 1    Lindsay Thomas           515-978-1565   46  Green, Trujillo and Dunn
# 2       Nathan Ross  +1-909-375-3513x93328   23             Golden-Bolton
# 3   Eric Carter Jr.     683-498-9471x96593   30               Johnson Ltd
# 4  Benjamin Shelton          (520)518-6848   61    Bryan, Barnes and Hill

# %%
df.tail()
# Out:
#                  Name       Mobile Number  Age                   Company
# 2995  Samantha Vaughn       (661)373-8760   54    Johnson, Ho and Taylor
# 2996  Brian Schroeder        295-963-4144   38                 White PLC
# 2997       Kelly Hall       (262)475-9766   49    Lang, Carr and Ramirez
# 2998  Reginald Morgan  406.249.5834x13567   58  Collins, Myers and Smith
# 2999       Kim Brooks        798-929-6996   38               Johnson Ltd

# %%
# !git clone https://github.com/lisha-goel/data-structures-and-algorithms.git
# Out:
# Cloning into 'data-structures-and-algorithms'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 21 (delta 4), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (21/21), 80.77 KiB | 4.49 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
ls
# Out:
# data-structures-and-algorithms/  generated_data.csv.1  sample_data/
# generated_data.csv               generated_data.csv.2

# %%
# !ls data-structures-and-algorithms/
# Out:
# generate_data.py  generated_data.csv  LICENSE  README.md

# %%
# !pwd
# Out:
# /content

# %%
df=pd.read_csv("data-structures-and-algorithms/generated_data.csv")

# %%
df.head()
# Out:
#                Name          Mobile Number  Age                   Company
# 0      Norma Fisher       487-364-7593x824   57              Archer-Patel
# 1    Lindsay Thomas           515-978-1565   46  Green, Trujillo and Dunn
# 2       Nathan Ross  +1-909-375-3513x93328   23             Golden-Bolton
# 3   Eric Carter Jr.     683-498-9471x96593   30               Johnson Ltd
# 4  Benjamin Shelton          (520)518-6848   61    Bryan, Barnes and Hill

# %%
# Filter the DataFrame based on names starting with 'A'
filtered_df = df[df['Name'].str.startswith('A')]

# Print or use the filtered DataFrame as needed
print(filtered_df)
# Out:
#                   Name           Mobile Number  Age  \
# 8        Amanda Garcia      (634)357-9230x2258   56
# 11       Amanda Savage        001-960-227-1427   20
# 13          Ariel Nash      (210)247-1428x5124   20
# 28        Angela Jones       (205)552-0351x923   60
# 34         Aimee Evans  001-348-692-6717x38640   60
# ...                ...                     ...  ...
# 2962     Anthony Jones   +1-643-235-1040x85406   39
# 2963    Alexandra Shaw            636.422.6819   60
# 2969  Antonio Campbell   001-376-299-3237x9083   24
# 2977  Ashley Henderson            650.651.5160   54
# 2983      Adam Jackson            730-372-6726   36
#
#                             Company
# 8                        Wade-Smith
# 11                    Nguyen-Monroe
# 13                       Becker PLC
# 28       Dennis, Santana and Adkins
# 34                      Smith Group
# ...                             ...
# 2962                  Berry-Pittman
# 2963              Blackburn-Mathews
# ...

# %%
len(filtered_df)
# Out:
# 287

# %% [markdown]
# ![Screenshot 2023-05-13 230909.png](data:image/png;base64,...)

# %% [markdown]
# [my notebook](https://https://colab.research.google.com/drive/1X4BrFoHOt_URNoKirl3_y6LVUVZgMO-b#scrollTo=YZpW3ffDK1nn)

# %% [markdown]
# $$ x1=\frac{a+\sqrt{b^2-4ac}}{b} $$
